# %% [markdown]
# # Reading API Documentation
#
# ## Introduction
# We've now covered an example API request, but how on Earth would you know how to do that on your own? The answer is through documentation! All APIs will have associated documentation, and while there are substantial similarities, all will be different to one degree or another. The best way to get more comfortable is to practice! So with that, let's take a look at the yelp documentation associated with our previous example.
#
# ## Objectives
#
# You will be able to:
#
# * Interpret API documentation into Python code
# * Make requests using OAuth
#
# Start by navigating to https://www.yelp.com/developers/documentation/v3/get_started and having a look for yourself!
#
# <img src="images/yelp_overview.png" width="800">
#
# As you see at the top, the first piece of almost every API is authentication.
#
# This is where we started in the previous codealong, where we went to https://www.yelp.com/developers/v3/manage_app and created a new app.
#
# <img src="images/yelp_app.png"  width="800">

# %% [markdown]
# Let's take a closer look at Yelp's authentication documentation:
# https://www.yelp.com/developers/documentation/v3/authentication
#
# <img src="images/yelp_auth.png" width="800">

# %% [markdown]
# Notice in the documentation, it gives us the specific format "Put the API Key in the request header as "Authorization: Bearer <YOUR API KEY>"." This is what we passed in our get request.
#
#
# Before we do this, let's import your authentication token which you have appropriately stored in **a separate file** from the codealong before.

# %%
import json

#Our previous function for loading our api key file
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %% [markdown]
# > **Note**: Like before, change the file path below to be your root directory.
# If you're not sure what your username is, check it with `pwd`
# For example, my current working directory is ```/Users/matthew.mitchell/Documents/dsc-using-yelp-api-codealong```
# So the line below would become:
# ```keys = get_keys("/Users/matthew.mitchell/.secret/yelp_api.json")```

# %%
keys = get_keys("/Users/jimpetoskey/.secret/yelp_api.json")

api_key = keys['api_key']

#While you may wish to print out these api keys to check that they imported properly,
#be sure to clear the output before uploading to Github. 
#Again, you don't want your keys stolen!!!

# %%
import requests

# %%
url = #This will be our next step
header = {"Authorization" : "Bearer {}".format(api_key)}
response = requests.get(url, header=header)
# Out:
#   File "<ipython-input-4-99271e4af878>", line 1
#     url = #This will be our next step
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
#  With that, let's take a look at how the rest of our request should be formatted. Go to https://www.yelp.com/developers/documentation/v3/business_search  and take a couple of minutes to look things over.
#
#  <img src="images/yelp_docs.png"  width="800">

# %% [markdown]
# Notice the first part is the format of the get request! This is the URL we pass into our get request. From there, the available parameters that you can pass are listed. These define your query, some are required while others are optional.
#
# Reviewing our python package we thus have:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC'
            }
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# Note that location or latitude and longitude are the only required parameters. That said, you are free to pass as many parameters as you want such as:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'Santa Fe',
                'term' : 'pizza',
                'limit' : 5,
                'price' : "1,2,3,4",
                'open_now' : True
            }
response = requests.get(url, headers=headers, params=url_params)
print(response.text)
# Out:
# {"businesses": [{"id": "ANqpydu0SBOfHAyuF99tsA", "alias": "pizza-centro-santa-fe-2", "name": "Pizza Centro", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/XBd0Vqp6_2iNomfvGPjsBQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/pizza-centro-santa-fe-2?adjust_creative=H1eoo-ciNH1FNAbpYMqzcw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H1eoo-ciNH1FNAbpYMqzcw", "review_count": 138, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "italian", "title": "Italian"}, {"alias": "gelato", "title": "Gelato"}], "rating": 4.0, "coordinates": {"latitude": 35.683940480192334, "longitude": -105.94364190222832}, "transactions": ["delivery"], "price": "$$", "location": {"address1": "418 Cerrillos Rd", "address2": "", "address3": "", "city": "Santa Fe", "zip_code": "87501", "country": "US", "state": "NM", "display_address": ["418 Cerrillos Rd", "Santa Fe, NM 87501"]}, "phone": "+15059888825", "display_phone": "(505) 988-8825", "distance": 2587.3500722999106}, {"id": "f6f5ddFYZ09tVlvnsJ7boQ", "alias": "back-road-pizza-santa-fe", "name": "Back Road Pizza", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/QlBleGGXcu-S7c4R-VVMhA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/back-road-pizza-santa-fe?adjust_creative=H1eoo-ciNH1FNAbpYMqzcw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H1eoo-ciNH1FNAbpYMqzcw", "review_count": 192, "categories": [{"alias": "pizza", "title": "Pizza"}], "rating": 3.5, "coordinates": {"latitude": 35.662791, "longitude": -105.965075}, "transactions": [], "price": "$$", "location": {"address1": "1807 2nd St", "address2": "Ste 1", "address3": "", "city": "Santa Fe", "zip_code": "87505", "country": "US", "state": "NM", "display_address": ["1807 2nd St", "Ste 1", "Santa Fe, NM 87505"]}, "phone": "+15059559055", "display_phone": "(505) 955-9055", "distance": 493.0382109755319}, {"id": "fo5g4vtd_ZBVj3oz3an0AA", "alias": "rooftop-pizzeria-santa-fe", "name": "Rooftop Pizzeria", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/sdWo-t7MdlPGVWd-fj-FjA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/rooftop-pizzeria-santa-fe?adjust_creative=H1eoo-ciNH1FNAbpYMqzcw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H1eoo-ciNH1FNAbpYMqzcw", "review_count": 442, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "italian", "title": "Italian"}], "rating": 3.5, "coordinates": {"latitude": 35.6865317242459, "longitude": -105.939468331753}, "transactions": ["delivery"], "price": "$$", "location": {"address1": "60 E San Francisco St", "address2": "", "address3": "", "city": "Santa Fe", "zip_code": "87501", "country": "US", "state": "NM", "display_address": ["60 E San Francisco St", "Santa Fe, NM 87501"]}, "phone": "+15059840008", "display_phone": "(505) 984-0008", "distance": 3044.5970958353805}, {"id": "CzkF1w_PtjfgHHd7IUSmdQ", "alias": "upper-crust-pizza-santa-fe", "name": "Upper Crust Pizza", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/_0ugvPTnNQOPz84z624XYA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/upper-crust-pizza-santa-fe?adjust_creative=H1eoo-ciNH1FNAbpYMqzcw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H1eoo-ciNH1FNAbpYMqzcw", "review_count": 313, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "salad", "title": "Salad"}, {"alias": "sandwiches", "title": "Sandwiches"}], "rating": 3.5, "coordinates": {"latitude": 35.68356, "longitude": -105.937161}, "transactions": ["delivery"], "price": "$$", "location": {"address1": "329 Old Santa Fe Trl", "address2": null, "address3": "", "city": "Santa Fe", "zip_code": "87501", "country": "US", "state": "NM", "display_address": ["329 Old Santa Fe Trl", "Santa Fe, NM 87501"]}, "phone": "+15059820000", "display_phone": "(505) 982-0000", "distance": 2938.08341437139}, {"id": "PsBjizM33y9aGat9fd-3Lw", "alias": "piccolino-santa-fe", "name": "Piccolino", "image_url": "https://s3-media2.fl.ye ...

# %% [markdown]
# The final important note is how some of the parameters have alternative formats. For example, `limit` is an integer and `open_now` is a boolean according to the documentation. Following these conventions is essential to receiving valid responses.
#
# # Summary
#
# Congratulations! Not only have you seen an API now, you've also practiced sifting through the documentation. The last piece in working with APIs is developing a more solid understanding of JSON files; the data format typically returned by modern APIs. Take some additional time and familiarize yourself with some further aspects of the documentation which you may wish to investigate in the upcoming lab!
